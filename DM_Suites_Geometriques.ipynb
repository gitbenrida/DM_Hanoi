# %% [markdown]
# <div align="center">La tours de HANOI</div>
# ## Première partie : présentation.
#
# Ce jeu célèbre a été inventé par le mathématicien français Édouard Anatole LUCAS (1842-1891) et publié en 1892.
#
# ![image-6.png](attachment:image-6.png)
# On dispose de trois piquets A, B, C.  Sur le piquet A,  sont disposés n disques troués, 2 à 2 de taille distincte, ils sont  rangés par taille décroissante en partant du bas.
#
# On veut déplacer les n disques sur le piquet C en respectant les 2 règles suivantes :
#     • On ne déplace qu'un seul disque à la fois et le disque déplacé doit être déplacé sur l'un des deux autres piquets. C'est ce que nous appellerons un déplacement.
#     • Un disque ne doit jamais être placé au-dessus d'un disque plus petit que lui.
# Le piquet B est utilisé pour les déplacements intermédiaires.
#
# On désigne par  le nombre minimal de déplacements nécessaires pour résoudre le problème.
#     1) Vérifier que , calculer   et  .
#        on pourra s'aider de simulations de la tour de Hanoï que l'on trouve très facilement sur internet, comme par exemple ici : http://jeux.prise2tete.fr/tour-de-hanoi/tour-de-hanoi.htm
#        afin de mieux comprendre le principe.
#
#     2) Pour déplacer les n disques de A vers C, il faudra, à un moment donné, déplacer le plus grand disque de A vers C, les n-1 autres étant alors correctement rangés sur B comme l'indique la figure ci-dessous.
#        Les n-1 disques de B étant ensuite déplacés sur C.
#        En déduire que pour tout ,
# ![image-5.png](attachment:image-5.png)
#
# ## Deuxième partie : étude de la suite.
#     1) Pour tout entier , on pose .
#        Calculer ,  et .
#        Montrer que  est une suite géométrique et préciser la valeur de son premier terme ainsi que sa raison.
#
#     2) Exprimer  en fonction de n, puis que pour tout , .
#
#     3) Après beaucoup d’entraînement, Édouard arrive à résoudre ce type de problème sans réfléchir. Il lui faut une seconde pour déplacer un disque d'un piquet à un autre.
#         a) Combien lui faut-il de temps pour résoudre le problème avec 20 disques ? (Édouard ne s'arrête pas, ni pour manger, ni pour dormir...)
#         b) Édouard attend son avion qui a 10 heures de retard et décide de s’entraîner un peu. Combien peut-il mettre de disque au maximum pour être sur de finir avant le départ de son avion ?
